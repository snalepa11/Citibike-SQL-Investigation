# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import statistics as stats

df = pd.read_csv("../data/citibike_weather_daily.csv")
df.head(20)
# Out:
#      ride_date  num_rides  avg_duration_min  temp_f  max_temp_f  min_temp_f  \
# 0   2013-07-01      16650             16.31    74.8        78.1        73.4
# 1   2013-07-02      22745             15.97    76.1        82.9        73.0
# 2   2013-07-03      21864             16.24    78.5        84.9        73.9
# 3   2013-07-04      22326             21.22    82.0        91.0        73.9
# 4   2013-07-05      21842             18.04    84.4        93.0        75.9
# 5   2013-07-06      20467             19.33    87.0        95.0        77.0
# 6   2013-07-07      20477             18.64    88.8        98.1        79.0
# 7   2013-07-08      21615             21.49    83.7        98.1        75.0
# 8   2013-07-09      26641             16.10    82.6        91.0        75.0
# 9   2013-07-10      25732             15.53    82.0        91.0        75.0
# 10  2013-07-11      24417             16.83    82.3        91.0        75.0
# ...

# %%
df.describe()
# Out:
#           num_rides  avg_duration_min       temp_f   max_temp_f   min_temp_f  \
# count   1610.000000       1610.000000  1610.000000  1610.000000  1610.000000
# mean   32986.783230         15.425584    57.368509    67.317081    49.295901
# std    16910.147968          3.652670    17.876211    18.349408    17.832318
# min      876.000000          9.500000     8.300000    18.000000     1.000000
# 25%    20505.500000         13.112500    43.625000    53.700000    35.700000
# 50%    32272.500000         14.860000    59.300000    70.000000    51.100000
# 75%    42915.750000         17.120000    73.500000    82.900000    64.900000
# max    78458.000000         81.110000    92.500000   100.900000    82.900000
#
#        wind_speed_knots    precip_in        month
# count       1610.000000  1610.000000  1610.000000
# mean           9.013913     0.178398     6.544099
# std            3.241211     2.508762     3.323772
# min            2.300000     0.000000     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ride_date         1610 non-null   str
#  1   num_rides         1610 non-null   int64
#  2   avg_duration_min  1610 non-null   float64
#  3   temp_f            1610 non-null   float64
#  4   max_temp_f        1610 non-null   float64
#  5   min_temp_f        1610 non-null   float64
#  6   wind_speed_knots  1610 non-null   float64
#  7   precip_in         1610 non-null   float64
#  8   day_of_week       1610 non-null   str
#  9   month             1610 non-null   int64
# dtypes: float64(6), int64(2), str(2)
# memory usage: 125.9 KB

# %%
plt.hist(df['num_rides'])
# Out:
# (array([112., 190., 197., 294., 341., 140., 138.,  99.,  75.,  24.]),
#  array([  876. ,  8634.2, 16392.4, 24150.6, 31908.8, 39667. , 47425.2,
#         55183.4, 62941.6, 70699.8, 78458. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['avg_duration_min'])
# Out:
# (array([1.151e+03, 4.310e+02, 2.500e+01, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 9.5  , 16.661, 23.822, 30.983, 38.144, 45.305, 52.466, 59.627,
#         66.788, 73.949, 81.11 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['max_temp_f'])
# Out:
# (array([ 18.,  57., 128., 156., 182., 202., 245., 275., 281.,  66.]),
#  array([ 18.  ,  26.29,  34.58,  42.87,  51.16,  59.45,  67.74,  76.03,
#          84.32,  92.61, 100.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['min_temp_f'])
# Out:
# (array([ 24.,  52., 105., 153., 234., 221., 239., 223., 285.,  74.]),
#  array([ 1.  ,  9.19, 17.38, 25.57, 33.76, 41.95, 50.14, 58.33, 66.52,
#         74.71, 82.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['precip_in'])
# Out:
# (array([1.609e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 0.   ,  9.999, 19.998, 29.997, 39.996, 49.995, 59.994, 69.993,
#         79.992, 89.991, 99.99 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['temp_f'])
# Out:
# (array([ 17.,  49., 116., 183., 212., 211., 247., 279., 252.,  44.]),
#  array([ 8.3 , 16.72, 25.14, 33.56, 41.98, 50.4 , 58.82, 67.24, 75.66,
#         84.08, 92.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['wind_speed_knots'])
# Out:
# (array([ 47., 283., 441., 379., 218., 135.,  56.,  33.,  10.,   8.]),
#  array([ 2.3 ,  4.31,  6.32,  8.33, 10.34, 12.35, 14.36, 16.37, 18.38,
#         20.39, 22.4 ]),
#  <BarContainer object of 10 artists>)

# %%
y = np.array(df['num_rides'])
x = np.array(df['max_temp_f'])
plt.scatter(x , y)

# %%
y = np.array(df['num_rides'])
x = np.array(df['min_temp_f'])
plt.scatter(x , y)

# %%
y = np.array(df['num_rides'])
x = np.array(df['wind_speed_knots'])
plt.scatter(x , y)

# %%
y = np.array(df['num_rides'])
x = np.array(df['precip_in'])

# Create bins in increments of 1, only showing 0-10
bins = list(range(0, 11, 1))
plt.scatter(x, y)
plt.xticks(bins)
plt.gca().set_xlim(left=-0.5, right=10.5)
# Out:
# (-0.5, 10.5)

# %%
y = np.array(df['num_rides'])
x = np.array(df['temp_f'])
plt.scatter(x , y)

# %% [markdown]
# Temp:
# Ridership peaks at around 60 degrees and declines with a sharp decline after 80 n\degrees.
# There are strong realtionships in general with temp. Ridership climbs as temperature does and dips after the temperature gets "too hot"
#
# Wind:
# The coorelation between ride numbers and wind is more scattered, although we do see a decrease in ridership after 12.5 knots.
#
# Rain:
# There is no linear realtionship. Ridership seems to decline as precipitation increases with few rides after 2in of precipitation.

# %%
# Convert ride_date to datetime and extract year
df['ride_date'] = pd.to_datetime(df['ride_date'])
df['year'] = df['ride_date'].dt.year
df['month'] = df['ride_date'].dt.month

# Get unique years
years = df['year'].unique()

# Create separate graph for each year showing monthly averages
for year in sorted(years):
    df_year = df[df['year'] == year]
    
    # Calculate average ridership per month
    monthly_avg = df_year.groupby('month')['num_rides'].mean()
    
    plt.figure(figsize=(10, 5))
    plt.bar(monthly_avg.index, monthly_avg.values)
    plt.title(f'Average Number of Rides per Month in {year}')
    plt.xlabel('Month')
    plt.ylabel('Average Number of Rides')
    plt.xticks(range(1, 13))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# E4 : September (9) seems to be the busiest month on average across all years. Months 6 (June) - 10 (October) seems to be the busiest months on average. We see a dip in ridership in the spring and winter months.

# %%
# Compare ridership across days of the week

# Define the order of days for proper sorting
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Calculate mean ridership by day of week
mean_by_day = df.groupby('day_of_week')['num_rides'].mean().reindex(day_order)

# Create bar chart of mean ridership
plt.figure(figsize=(10, 5))
plt.bar(day_order, mean_by_day)
plt.title('Mean Ridership by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Mean Number of Rides')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create box plots
plt.figure(figsize=(12, 6))
df['day_of_week'] = pd.Categorical(df['day_of_week'], categories=day_order, ordered=True)
df_sorted = df.sort_values('day_of_week')
df_sorted.boxplot(column='num_rides', by='day_of_week', figsize=(12, 6))
plt.title('Distribution of Ridership by Day of Week')
plt.suptitle('')  # Remove default title
plt.xlabel('Day of Week')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print statistics
print("Mean ridership by day of week:")
print(mean_by_day.round(0))

#E5 : Based on the graphs below, I would think it's safe to say that bike users are primarily commuters as we can see an uptick of usage during week days and a dip over the weekend.
# Out:
# Mean ridership by day of week:
# day_of_week
# Monday       33297.0
# Tuesday      35485.0
# Wednesday    36265.0
# Thursday     35738.0
# Friday       34229.0
# Saturday     28563.0
# Sunday       27261.0
# Name: num_rides, dtype: float64

# %% [markdown]
# E6 : There are 186 days missing - this is due to some days not having any recorded data and therefore being deleted altogether due to the join.
